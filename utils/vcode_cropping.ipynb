# %%
from matplotlib import pyplot as plt
import nibabel as nb

subject='sub-004'

# %%
img=nb.load(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/masked_mp2rage/{subject}/ses-1/anat/{subject}_ses-1_acq-MP2RAGE_desc-masked_T1w.nii.gz')
print(img.shape)
img.orthoview()
plt.show()
# Out:
# (461, 769, 769)

# %%
cropped=img.slicer[:,65:-65,65:-65]
#cropped=img.slicer[:,10:-10,10:-10]
print(cropped.shape)
cropped.orthoview()
plt.show()

# %%
#img.to_filename(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/upsampling/{subject}/ses-1/anat/{subject}_ses-1_acq-MP2RAGE_desc-masked_T1w_hires.nii.gz')

# %%
cropped.to_filename(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/masked_mp2rage/{subject}/ses-1/anat/{subject}_ses-1_acq-MP2RAGE_desc-masked_T1w.nii.gz')

# %%
img=nb.load(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/{subject}/ses-1/anat/{subject}_ses-1_acq-3DTSE_T2w.nii.gz')
print(img.shape)
img.orthoview()
plt.show()
# Out:
# (461, 769, 769)

# %%
cropped=img.slicer[:,65:-65,65:-65]
#cropped=img.slicer[:,10:-10,10:-10]
print(cropped.shape)
cropped.orthoview()
plt.show()

# %%
cropped.to_filename(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/{subject}/ses-1/anat/{subject}_ses-1_acq-3DTSE_T2w.nii.gz')
