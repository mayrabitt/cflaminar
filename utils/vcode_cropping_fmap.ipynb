# %%
from matplotlib import pyplot as plt
import nibabel as nb
subject='sub-001'

# %%
img=nb.load(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/{subject}/ses-1/fmap/{subject}_ses-1_task-ret_run-2_epi.nii.gz')
img.shape
# Out:
# (160, 47, 160, 3)

# %%
cropped=img.slicer[:,:-1,:,:]
cropped.orthoview()
plt.show()
print(cropped.shape)
# Out:
# (160, 46, 160, 3)

# %%
cropped.to_filename(f'/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/{subject}/ses-1/fmap/{subject}_ses-1_task-ret_run-2_epi.nii.gz')
