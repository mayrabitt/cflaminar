# %%
from matplotlib import pyplot as plt
import nibabel as nb

# %%
img=nb.load('/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/upsampling/sub-002/ses-1/anat/sub-002_ses-1_acq-MP2RAGE_desc-masked_T1w.nii.gz')
img.shape
# Out:
# (461, 742, 742)

# %%
cropped=img.slicer[:,65:-65,65:-65]
cropped.orthoview()
plt.show()

# %%
img.to_filename('/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/upsampling/sub-002/ses-1/anat/sub-002_ses-1_acq-MP2RAGE_desc-masked_T1w_hires.nii.gz')

# %%
cropped.to_filename('/data1/projects/dumoulinlab/Lab_members/Mayra/projects/CFLamUp/derivatives/upsampling/sub-002/ses-1/anat/sub-002_ses-1_acq-MP2RAGE_desc-croppedmasked_T1w.nii.gz')
